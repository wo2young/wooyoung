# %% [markdown]
# # Pandas의 시각화 기능

# %% [markdown]
# Pandas의 시리즈나 데이터프레임은 `plot`이라는 시각화 메서드를 내장하고 있다. `plot`은 matplotlib를 내부에서 임포트하여 사용한다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.randn(100,3)
# Out:
# array([[-1.01914456,  0.6099382 , -0.35143495],
#        [ 0.01306635, -1.69808538, -0.57118366],
#        [-0.01095743,  0.77679991, -2.04950412],
#        [-0.39254904, -1.73382615, -0.92617731],
#        [ 0.89357864, -0.04379108,  0.39699323],
#        [-0.71565584,  0.31897742, -1.37680945],
#        [-1.91409782,  1.54531339,  0.38804952],
#        [ 1.08663621,  0.35230849, -0.66408823],
#        [-1.00895506,  0.4828172 ,  0.94853942],
#        [-1.78434906, -0.22118572, -0.56614949],
#        [ 0.25607315, -0.20236716,  0.21039313],
#        [ 1.05694056,  0.35749467,  1.57734487],
#        [-1.22788678,  1.78618663,  0.70183291],
#        [-0.27914434,  0.9819629 , -0.3973769 ],
#        [-2.84434634,  1.03046554, -0.25980635],
#        [-0.45890325, -0.38730533, -1.71301574],
#        [ 0.3848519 , -0.47296287,  0.04609048],
#        [-1.39168694, -0.3382861 , -0.91065746],
#        [ 0.58710563, -0.85579294,  0.76604248],
#        [ 0.97534316, -0.68123183, -1.5130748 ],
#        [-1.91631764, -1.10631546,  0.68005562],
#        [ 1.17693836,  0.31160232, -1.90137154],
#        [ 0.16688494,  1.9301624 ,  1.92998741],
#        [ 0.7058814 , -1.70497811, -0.84039884],
#        [ 0.49833184,  0.80663603,  0.94000068],
#        [-0.86250541, -0.11867755,  2.27244327],
#        [-1.16607261,  0.41113474, -2.10981538],
#        [ 0.29441537,  1.53310548,  1.82700669],
#        [ 0.15928405, -0.01254733, -0.55602951],
#        [ 0.14422082,  0.88163079,  1.27023096],
#        [-0.12758771,  0.29856332,  1.25136258],
#        [ 1.23568349, -0.21720708,  0.96447031],
#        [ 0.64447663, -1.3795116 ,  1.11229513],
#        [ 0.96924667, -1.37926507, -1.53375778],
#        [ 1.90683505,  0.55892768,  0.33044056],
#        [ 0.23582986, -2.06736734,  0.30678836],
#        [-0.62703873,  0.83120518,  0.59803062],
#        [-0.02495585,  0.47851524,  1.80825539],
#        [ 0.23099951, -0.13351365, -1.31434559],
#        [-0.42862536, -1.80046678, -0.67999147],
#        [-0.28749186, -0.30134973,  1.3612351 ],
#        [ 1.43374117, -0.67841199,  0.22717632],
#        [ 0.10710367, -0.43408092, -0.45810042],
#        [ 0.1262761 ,  1.26854538, -0.51722999],
#        [ 0.69166662,  0.32803272,  1.97515944],
#        [-2.21118815, -0.2673875 , -0.46595337],
#        [-1.03084399,  1.36341826,  0.39075962],
#        [ 1.45807195,  0.42453908, -0.60515664],
#        [-0.024384  ,  1.87165971, -0.7304508 ],
#        [-1.16223045,  0.43002219,  1.22859121],
#        [ 0.4519729 ,  0.08143143, -0.56788332],
#        [ 0.09517854, -1.46208234,  1.71461986],
#        [ 0.67372711,  0.7428634 , -2.69771584],
#        [-0.91482371,  0.17233262,  0.49730963],
#        [-0.25010487, -0.47177717,  0.43843059],
#        [ 0.1246801 , -0.38923315,  1.99054496],
#        [-0.1084504 , -1.43818144, -0.65958164],
#        [ 0.50445978, -1.09994136, -1.24932834],
#        [-0.96745302,  0.60007061, -1.27414759],
#        [ 1.08687299, -1.87388362,  0.2682773 ],
#        [-1.47198951,  0.84640955,  0.04157084],
#        [ 0.0034086 , -0.83290879, -0.10352821],
#        [ 1.10309717,  0.11154802, -1.15239851],
#        [ 1.33440693, -1.06051712, -1.92973564],
#        [ 0.30405333,  0.72675286, -1.36099861],
#        [-0.98740376,  0.33659024, -0.90107504],
#        [-0.30165282, -0.50557456,  1.36652566],
#        [ 0.08728206,  0.64741018, -2.457221  ],
#        [ 0.18997369,  0.15527636, -0.36339489],
#        [-1.05810218,  1.38663726, -1.96323002],
#        [-0.15897262,  0.9432331 ,  0.06532235],
#        [ 0.31188183,  0.47640955,  0.91956667],
#        [ 0.17722491,  0.63234044,  0.48352596],
#        [-0.20365647, -0.35570483,  0.89181736],
#        [ 0.2601698 , -0.28716663, -1.24557831],
#        [ 2.11981209, -0.06791329,  1.47489019],
#        [-0.06790593, -1.39395178, -0.86212661],
#        [-1.56857663, -1.09844878, -0.14104565],
#        [ 0.26872159, -0.67688182, -0.51933206],
#        [ 1.26528533, -0.94796216, -0.76984884],
#        [ 0.1112757 ,  0.32732802, -0.76863813],
#        [ 0.46819598, -0.52275625, -0.17132368],
#        [ 0.15490541,  1.66169256,  1.0688209 ],
#        [ 1.02482462, -0.95667172, -0.13126317],
#        [ 0.05611597,  0.38975065, -0.71208083],
#        [ 1.28975152, -1.12447566, -0.78076367],
#        [ 1.08078334,  0.26064823,  0.69486012],
#        [-1.27710351,  0.14328422,  1.03252301],
#        [ 1.52388402,  0.48878761, -0.24719053],
#        [-2.24955451, -0.39970926, -0.51036627],
#        [-2.30026192, -0.36374332,  0.71237115],
#        [ 0.42498327, -0.27293752,  0.33088326],
#        [-0.57003649,  0.41542981, -0.54667734],
#        [-1.40327239,  0.19806634,  0.28441667],
#        [-0.91308181, -0.2989277 ,  1.50271763],
#        [-1.49232475, -0.24677571,  0.18111869],
#        [ 1.09636471, -1.96831061, -0.01592995],
#        [-1.44503231,  1.93143192,  2.36012826],
#        [-1.30552398, -0.09569915, -0.65510714],
#        [ 0.18655465, -1.92167625, -1.25788723]])

# %%
np.random.seed()
df1 = pd.DataFrame(np.random.randn(100, 3),
                   index=pd.date_range('1/1/2020', periods=100),
                   columns=['A', 'B', 'C'])
df1
# Out:
#                    A         B         C
# 2020-01-01 -2.803142 -0.593646  0.316180
# 2020-01-02 -1.193699  1.815733  0.886564
# 2020-01-03  0.950058  0.833144 -0.224443
# 2020-01-04 -1.348871 -0.528873  1.347527
# 2020-01-05  0.654157  1.643663  0.599048
# ...              ...       ...       ...
# 2020-04-05  0.243973 -1.314005  1.191954
# 2020-04-06 -0.798352  0.020131 -1.242558
# 2020-04-07 -0.106518 -0.137385 -0.979937
# 2020-04-08 -0.668530  1.593544 -0.135663
# 2020-04-09  0.538248  0.062934 -0.957178
#
# [100 rows x 3 columns]

# %%
df_cumsum = df1.cumsum() # 누적합
df_cumsum
# Out:
#                    A         B         C
# 2020-01-01 -2.803142 -0.593646  0.316180
# 2020-01-02 -3.996842  1.222087  1.202745
# 2020-01-03 -3.046784  2.055231  0.978302
# 2020-01-04 -4.395655  1.526358  2.325828
# 2020-01-05 -3.741498  3.170022  2.924877
# ...              ...       ...       ...
# 2020-04-05 -2.482809 -7.594260 -0.288786
# 2020-04-06 -3.281161 -7.574129 -1.531344
# 2020-04-07 -3.387679 -7.711513 -2.511281
# 2020-04-08 -4.056209 -6.117970 -2.646944
# 2020-04-09 -3.517961 -6.055036 -3.604122
#
# [100 rows x 3 columns]

# %%
plt.figure(figsize=(10, 2))
df_cumsum.plot()
# Out:
# <Axes: >

# %% [markdown]
# `plot` 메서드의 `kind`라는 인수를 바꾸면 여러가지 플롯을 그릴 수 있다. 다음과 같은 인수값을 지원한다.
#
# * `bar`
# * `pie`
# * `hist`
# * `kde`
# * `box`
# * `scatter`
# * `area`

# %%
import seaborn as sns
iris = sns.load_dataset("iris")    # 붓꽃 데이터
titanic = sns.load_dataset("titanic")    # 타이타닉호 데이터

# %% [markdown]
# `kind` 인수에 문자열을 쓰는 대신 `plot.bar`처럼 직접 메서드로 사용할 수도 있다.

# %%
iris[:10].plot(figsize=(10,3), kind='bar')
# Out:
# <Axes: >

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
iris[:5].plot.bar(rot=0)
plt.title("Iris 데이터의 Bar Plot")
plt.xlabel("Data")
plt.ylabel("각 Feature의 값")
plt.ylim(0, 7)
plt.show()

# %% [markdown]
# 다음은 그룹분석으로 각 붓꽃종의 특징값의 평균을 구한 것이다.

# %%
df2 = iris.groupby(iris.species).mean()
df2.columns.name = "feature"  # in-place method
df2
# Out:
# feature     sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %% [markdown]
# 그룹분석 결과도 데이터프레임이므로 같은 방식으로 시각화할 수 있다.

# %%
iris[:5].plot.bar(rot=0)
plt.title("Iris 데이터의 Bar Plot")
plt.xlabel("Data")
plt.ylabel("각 Feature의 값")
plt.ylim(0, 7)
plt.show()

# %% [markdown]
# 전치연산으로 시각화 방법을 다르게 할 수도 있다.

# %% [markdown]
# 다음은 ``pie``,  ``hist``, ``kde``, ``box``, ``scatter`` 플롯 예제이다.

# %%
df3 = titanic['class'].value_counts()
df3
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
df3.plot.pie(autopct="%.2f%%")
plt.title("선실별 승객 수의 비율")
plt.show()

# %%
iris.plot.hist()
plt.title("각 Feature 값들의 빈도수 Histogram")
plt.xlabel("단위 (cm)")
plt.show()

# %%
iris.plot.kde()
plt.title("각 Feature 값들의 빈도수 kde")
plt.xlabel("단위 (cm)")
plt.show()

# %%
iris.plot.box()
plt.title("각 Feature 값들의 빈도수 box plot")
plt.xlabel("단위 (cm)")
plt.show()

# %%
iris.boxplot(by='species', figsize=(8, 7))
plt.tight_layout(pad=3, h_pad=2)
plt.title("각 Feature의 종 별 데이터에 대한 Box Plot")
plt.show()

# %% [markdown]
# 박스플롯에 대해서는 추가적인 기능을 가진 `boxplot` 명령이 별도로 있다.
