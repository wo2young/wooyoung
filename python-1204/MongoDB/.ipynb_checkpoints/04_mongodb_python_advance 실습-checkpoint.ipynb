# %% [markdown]
# ## **04 MongoDB Python Advance**

# %% [markdown]
# ### 0. 기본 pymongo 템플릿 코드
# > sample_mflix 데이터셋을 기반으로, 지금까지 익힌 mongodb 문법을 pymongo 에서 어떻게 적용해서 사용할 수 있는지를 알아보기로 함

# %%
from pymongo import MongoClient

# MongoDB에 연결 (인증 미필요시)
client = MongoClient("mongodb://localhost:27017")
# client = MongoClient("mongodb://username:password@localhost:27017")
# 인증이 필요하지 않은 경우 위의 첫 번째 줄 사용, 인증이 필요한 경우 두 번째 줄 사용

db = client.sample_mflix   # use sample_mflix (데이터베이스 선택)
movies = db.movies         # 'movies' collection 선택

# %%
movies
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'sample_mflix'), 'movies')

# %% [markdown]
# ### 다양한 find() 문법 적용
#
# **1. 프로젝션(projection) - 결과 문서에 표시할 필드 지정:**

# %%
movies.find({"year": 1923}, {"_id": 0, "title": 1, "year": 1}) 
# db.movies.find( { year: 1923 }, { _id: 0, title: 1, year: 1 } )

# %%
for movie in movies.find({"year": 1923}, {"_id": 0, "title": 1, "year": 1}):
    print(movie, movie['year'])
# Out:
# {'title': 'The Hunchback of Notre Dame', 'year': 1923} 1923
# {'title': 'Our Hospitality', 'year': 1923} 1923
# {'title': 'Safety Last!', 'year': 1923} 1923
# {'title': 'Three Ages', 'year': 1923} 1923
# {'title': 'A Woman of Paris: A Drama of Fate', 'year': 1923} 1923
# {'title': 'The Chechahcos', 'year': 1923} 1923

# %%
type(movie)
# Out:
# dict

# %% [markdown]
# **2. 비교 쿼리 연산자 - MongoDB 비교 쿼리 연산자 사용:**

# %%
list(movies.find({"year": {"$lt": 1910}}, {"_id": 0, "title": 1, "year": 1})) 
# db.movies.find( { year: { $lt: 1910 } }, { _id: 0, title: 1, year: 1 } )
# Out:
# [{'title': 'Blacksmith Scene', 'year': 1893},
#  {'title': 'The Great Train Robbery', 'year': 1903},
#  {'title': 'A Corner in Wheat', 'year': 1909},
#  {'title': 'The Kiss', 'year': 1896},
#  {'title': 'Dickson Experimental Sound Film', 'year': 1894},
#  {'title': 'The Kiss', 'year': 1896},
#  {'title': 'Newark Athlete', 'year': 1891}]

# %%
# 1910년 이전에 출시된 영화 찾기
for movie in movies.find({"year": {"$lt": 1910}}, {"_id": 0, "title": 1, "year": 1}):
    print(movie)
# Out:
# {'title': 'Blacksmith Scene', 'year': 1893}
# {'title': 'The Great Train Robbery', 'year': 1903}
# {'title': 'A Corner in Wheat', 'year': 1909}
# {'title': 'The Kiss', 'year': 1896}
# {'title': 'Dickson Experimental Sound Film', 'year': 1894}
# {'title': 'The Kiss', 'year': 1896}
# {'title': 'Newark Athlete', 'year': 1891}

# %% [markdown]
# **3. 논리 쿼리 연산자 - MongoDB 논리 쿼리 연산자 사용:**

# %%
# 1900년 이전 또는 2015년 이후에 출시된 영화 찾기
for movie in movies.find(
        {"$or": [{"year": {"$lt": 1900}}, {"year": {"$gt": 2015}}]},
        {"_id": 0, "title": 1, "year": 1}
):
    print(movie)
# Out:
# {'title': 'Blacksmith Scene', 'year': 1893}
# {'title': 'The Kiss', 'year': 1896}
# {'title': 'Dickson Experimental Sound Film', 'year': 1894}
# {'title': 'The Kiss', 'year': 1896}
# {'title': 'Newark Athlete', 'year': 1891}
# {'title': 'The Masked Saint', 'year': 2016}

# %% [markdown]
# **4. 배열 쿼리 연산자 - MongoDB 배열 쿼리 연산자 사용:**

# %%
# 'Action'과 'Sci-Fi' 장르의 영화 찾기
for movie in movies.find(
        {"genres": {"$all": ["Action", "Sci-Fi"]}},
        {"_id": 0, "title": 1, "year": 1, "genres": 1}
):
    print(movie)
# Out:
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Flash Gordon', 'year': 1936}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'The War of the Worlds', 'year': 1953}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'The 10th Victim', 'year': 1965}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Das Millionenspiel', 'year': 1970}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Battle for the Planet of the Apes', 'year': 1973}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Westworld', 'year': 1973}
# {'genres': ['Action', 'Sci-Fi', 'Sport'], 'title': 'Rollerball', 'year': 1975}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Buck Rogers in the 25th Century', 'year': 1979}
# {'year': 1978, 'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Superman'}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Message from Space', 'year': 1978}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Mad Max', 'year': 1979}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'The Chain Reaction', 'year': 1980}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'The Final Countdown', 'year': 1980}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Flash Gordon', 'year': 1980}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Kuruizaki sanda rodo', 'year': 1980}
# {'year': 1980, 'genres': ['Action', 'Romance', 'Sci-Fi'], 'title': 'Superman II'}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Escape from New York', 'year': 1981}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'For Your Eyes Only', 'year': 1981}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Mad Max 2: The Road Warrior', 'year': 1981}
# {'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Outland', 'year': 1981}
# {'genres': ['Sci-Fi', 'Action'], 'title': 'Megaforce', 'year': 1982}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'TRON', 'year': 1982}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Battletruck', 'year': 1982}
# {'genres': ['Adventure', 'Sci-Fi', 'Action'], 'title': 'Metalstorm: The Destruction of Jared-Syn', 'year': 1983}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Space Raiders', 'year': 1983}
# {'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': 'Superman III', 'year': 1983}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Timerider: The Adventure of Lyle Swann', 'year': 1982}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'V: The Final Battle', 'year': 1984}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Dune', 'year': 1984}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Firestarter', 'year': 1984}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Godzilla 1985', 'year': 1984}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'The Last Starfighter', 'year': 1984}
# {'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Runaway', 'year': 1984}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Star Trek III: The Search for Spock', 'year': 1984}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'The Terminator', 'year': 1984}
# {'genres': ['Sci-Fi', 'Action', 'Drama'], 'title': 'City Limits', 'year': 1984}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Lifeforce', 'year': 1985}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Mad Max Beyond Thunderdome', 'year': 1985}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Aliens', 'year': 1986}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Black Moon Rising', 'year': 1986}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Solarbabies', 'year': 1986}
# {'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': 'Leonard Part 6', 'year': 1987}
# {'year': 1987, 'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Predator'}
# {'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'RoboCop', 'year': 1987}
# {'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'The Running Man', 'year': 1987}
# {'year': 1988, 'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': 'Akira'}
# {'year': 1988, 'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Alien Nation'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'They Live', 'year': 1988}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Watchers', 'year': 1988}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'World Gone Wild', 'year': 1987}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Moon 44', 'year': 1990}
# {'year': 1989, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Star Trek V: The Final Frontier'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Class of 1999', 'year': 1989}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Hardware', 'year': 1990}
# {'genres': ['Action', 'Sci-Fi', 'Horror'], 'title': 'Death Street USA', 'year': 1988}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Predator 2', 'year': 1990}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'RoboCop 2', 'year': 1990}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Total Recall', 'year': 1990}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Until the End of the World', 'year': 1991}
# {'genres': ['Sci-Fi', 'Action', 'Comedy'], 'title': 'Guyver', 'year': 1991}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Robot Jox', 'year': 1989}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Scanners II: The New Order', 'year': 1991}
# {'year': 1991, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Star Trek VI: The Undiscovered Country'}
# {'year': 1991, 'genres': ['Action', 'Sci-Fi'], 'title': 'Terminator 2: Judgment Day'}
# {'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Freejack', 'year': 1992}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Shadowchaser', 'year': 1992}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Timebomb', 'year': 1991}
# {'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': 'Accièn mutante', 'year': 1993}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Babylon 5: The Gathering', 'year': 1993}
# {'year': 1993, 'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Demolition Man'}
# {'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Fortress', 'year': 1992}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'A.P.E.X.', 'year': 1994}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Death Machine', 'year': 1994}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'No Escape', 'year': 1994}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Phantasm III: Lord of the Dead', 'year': 1994}
# {'year': 1994, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Stargate'}
# {'year': 1994, 'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Timecop'}
# {'year': 1995, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'GoldenEye'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Godzilla vs. Destoroyah', 'year': 1995}
# {'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Johnny Mnemonic', 'year': 1995}
# {'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Judge Dredd', 'year': 1995}
# {'year': 1995, 'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Virtuosity'}
# {'year': 1995, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Waterworld'}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'The Arrival', 'year': 1996}
# {'year': 1996, 'genres': ['Action', 'Sci-Fi'], 'title': 'Barb Wire'}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Chain Reaction', 'year': 1996}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Drive', 'year': 1997}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Escape from L.A.', 'year': 1996}
# {'year': 1996, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Independence Day'}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Lawnmower Man 2: Beyond Cyberspace', 'year': 1996}
# {'year': 1996, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Star Trek: First Contact'}
# {'genres': ['Action', 'Short', 'Sci-Fi'], 'title': 'T2 3-D: Battle Across Time', 'year': 1996}
# {'genres': ['Action', 'Sci-Fi', 'Animation'], 'title': 'Werner - Das muss kesseln!!!', 'year': 1996}
# {'year': 1997, 'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Alien: Resurrection'}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'The Avengers', 'year': 1998}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'DNA', 'year': 1997}
# {'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': 'Double Team', 'year': 1997}
# {'year': 1997, 'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Face/Off'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'DNA', 'year': 1997}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'The Lost World: Jurassic Park', 'year': 1997}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': "Smilla's Feeling for Snow", 'year': 1997}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Soldier', 'year': 1998}
# {'year': 1997, 'genres': ['Action', 'Sci-Fi', 'War'], 'title': 'Starship Troopers'}
# {'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Steel', 'year': 1997}
# {'year': 1997, 'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Volcano'}
# {'year': 1998, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Armageddon'}
# {'year': 1998, 'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Deep Impact'}
# {'year': 2005, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Fantastic Four'}
# {'year': 1998, 'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Godzilla'}
# {'year': 1998, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Star Trek: Insurrection'}
# {'year': 2000, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'X-Men'}
# {'year': 1999, 'genres': ['Action', 'Sci-Fi'], 'title': 'The Matrix'}
# {'year': 2001, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Planet of the Apes'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Pitch Black', 'year': 2000}
# {'year': 1999, 'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Deep Blue Sea'}
# {'year': 2000, 'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Pitch Black'}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Message from Space', 'year': 1978}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Deep Blue Sea', 'year': 1999}
# {'year': 2001, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Jurassic Park III'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Scanners II: The New Order', 'year': 1991}
# {'year': 2004, 'genres': ['Action', 'Fantasy', 'Sci-Fi'], 'title': 'Hellboy'}
# {'year': 2002, 'genres': ['Comedy', 'Action', 'Sci-Fi'], 'title': 'The Adventures of Pluto Nash'}
# {'year': 2002, 'genres': ['Action', 'Mystery', 'Sci-Fi'], 'title': 'Minority Report'}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Terminator 3: Rise of the Machines', 'year': 2003}
# {'year': 2000, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Battlefield Earth'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Blade II', 'year': 2002}
# {'year': 2001, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Jurassic Park III'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Godzilla, King of the Monsters!', 'year': 1956}
# {'year': 2000, 'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Red Planet'}
# {'year': 2000, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'X-Men'}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Thrill Seekers', 'year': 1999}
# {'year': 2000, 'genres': ['Action', 'Mystery', 'Sci-Fi'], 'title': 'The 6th Day'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Ghosts of Mars', 'year': 2001}
# {'year': 2003, 'genres': ['Action', 'Sci-Fi'], 'title': 'The Matrix Reloaded'}
# {'year': 2002, 'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Equilibrium'}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Replicant', 'year': 2001}
# {'year': 2003, 'genres': ['Action', 'Sci-Fi'], 'title': 'The Matrix Revolutions'}
# {'genres': ['Action', 'Sci-Fi', 'Sport'], 'title': 'Rollerball', 'year': 2002}
# {'year': 2001, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Planet of the Apes'}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Gen-X Cops 2: Metal Mayhem', 'year': 2000}
# {'year': 2002, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Star Trek: Nemesis'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Godzilla vs. Megaguirus', 'year': 2000}
# {'year': 2000, 'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Battle Royale'}
# {'year': 2001, 'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'The One'}
# {'year': 2002, 'genres': ['Sci-Fi', 'Adventure', 'Action'], 'title': 'The Time Machine'}
# {'year': 1988, 'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': 'Akira'}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Hulk', 'year': 2003}
# {'year': 2002, 'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': 'The Tuxedo'}
# {'year': 2003, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'X-Men 2'}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': '2009 Loseuteu maemorijeu', 'year': 2002}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'The Chronicles of Riddick', 'year': 2004}
# {'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Ballistic: Ecks vs. Sever', 'year': 2002}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'The Princess Blade', 'year': 2001}
# {'year': 2004, 'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Resident Evil: Apocalypse'}
# {'year': 2004, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'The Day After Tomorrow'}
# {'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': 'Resurrection of the Little Match Girl', 'year': 2002}
# {'year': 2003, 'genres': ['Action', 'Mystery', 'Sci-Fi'], 'title': 'Paycheck'}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Battle Royale II', 'year': 2003}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Returner', 'year': 2002}
# {'year': 2004, 'genres': ['Action', 'Mystery', 'Sci-Fi'], 'title': 'I, Robot'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Dawn of the Dead', 'year': 2004}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'The Final Cut', 'year': 2004}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Babylon A.D.', 'year': 2008}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Moon Child', 'year': 2003}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Jurassic World', 'year': 2015}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Ultraviolet', 'year': 2006}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'AVP: Alien vs. Predator', 'year': 2004}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Iron Man', 'year': 2008}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'X-Men: The Last Stand', 'year': 2006}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Naechureol siti', 'year': 2003}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Serenity', 'year': 2005}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Stealth', 'year': 2005}
# {'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': 'Renaissance', 'year': 2006}
# {'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': 'The Girl from Monday', 'year': 2005}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'The Island', 'year': 2005}
# {'year': 2006, 'genres': ['Action', 'Fantasy', 'Sci-Fi'], 'title': 'Underworld: Evolution'}
# {'year': 2005, 'genres': ['Action', 'Sci-Fi'], 'title': 'èon Flux'}
# {'year': 2006, 'genres': ['Action', 'Fantasy', 'Sci-Fi'], 'title': 'Underworld: Evolution'}
# {'genres': ['Action', 'Animation', 'Sci-Fi'], 'title': 'The Chronicles of Riddick: Dark Fury', 'year': 2004}
# {'year': 2009, 'genres': ['Action', 'Mystery', 'Sci-Fi'], 'title': 'Watchmen'}
# {'year': 2011, 'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Cowboys & Aliens'}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Kampfansage - Der letzte Schèler', 'year': 2005}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Transformers', 'year': 2007}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Doom', 'year': 2005}
# {'year': 2008, 'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': 'Superhero Movie'}
# {'year': 2007, 'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Resident Evil: Extinction'}
# {'year': 2011, 'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Real Steel'}
# {'year': 2007, 'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Next'}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'The Gene Generation', 'year': 2007}
# {'year': 2009, 'genres': ['Action', 'Sci-Fi'], 'title': 'Terminator Salvation'}
# {'genres': ['Sci-Fi', 'Action', 'Adventure'], 'title': 'Mysterious Island', 'year': 2005}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Death Race', 'year': 2008}
# {'year': 2006, 'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Deja Vu'}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Captain America: The First Avenger', 'year': 2011}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'X-Men Origins: Wolverine', 'year': 2009}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Paragraph 78', 'year': 2007}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Outlander', 'year': 2008}
# {'year': 2009, 'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Push'}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Category 7: The End of the World', 'year': 2005}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Hollow Man II', 'year': 2006}
# {'genres': ['Action', 'Romance', 'Sci-Fi'], 'title': 'The Sword Bearer', 'year': 2006}
# {'year': 2015, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Ant-Man'}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Jumper', 'year': 2008}
# {'year': 2007, 'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Aliens vs. Predator: Requiem'}
# {'year': 2009, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Star Trek'}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'The Incredible Hulk', 'year': 2008}
# {'year': 2014, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Godzilla'}
# {'year': 2012, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'The Avengers'}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Obitaemyy ostrov', 'year': 2009}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Battlestar Galactica: Razor', 'year': 2007}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Alien Raiders', 'year': 2008}
# {'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': "Get Smart's Bruce and Lloyd Out of Control", 'year': 2008}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Gamer', 'year': 2009}
# {'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': 'Iron Sky', 'year': 2012}
# {'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Eyeborgs', 'year': 2009}
# {'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': 'Appleseed Saga: Ex Machina', 'year': 2007}
# {'year': 2009, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'G.I. Joe: The Rise of Cobra'}
# {'year': 2010, 'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Repo Men'}
# {'year': 2009, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Transformers: Revenge of the Fallen'}
# {'year': 2009, 'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'District 9'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'The Colony', 'year': 2013}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Tetsuo: The Bullet Man', 'year': 2009}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Tokyo Gore Police', 'year': 2008}
# {'year': 2009, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 2012}
# {'year': 2013, 'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': "The World's End"}
# {'year': 2011, 'genres': ['Action', 'Sci-Fi'], 'title': 'Battle Los Angeles'}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Iron Man 2', 'year': 2010}
# {'year': 2014, 'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'RoboCop'}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Interceptor', 'year': 2009}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'X-Men: First Class', 'year': 2011}
# {'year': 2012, 'genres': ['Action', 'Crime', 'Sci-Fi'], 'title': 'Looper'}
# {'year': 2012, 'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': 'The Watch'}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Iron Man 3', 'year': 2013}
# {'genres': ['Action', 'Romance', 'Sci-Fi'], 'title': 'Enthiran', 'year': 2010}
# {'year': 2011, 'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Rise of the Planet of the Apes'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'The Day of the Triffids', 'year': 2009}
# {'year': 2015, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Terminator Genisys'}
# {'year': 2012, 'genres': ['Action', 'Sci-Fi'], 'title': 'Dredd'}
# {'year': 2010, 'genres': ['Action', 'Mystery', 'Sci-Fi'], 'title': 'Inception'}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Time Again', 'year': 2011}
# {'year': 2015, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Mad Max: Fury Road'}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Transformers: Dark of the Moon', 'year': 2011}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Obitaemyy ostrov. Skhvatka', 'year': 2009}
# {'year': 2013, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Star Trek Into Darkness'}
# {'year': 2012, 'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': 'Men in Black 3'}
# {'year': 2013, 'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Riddick'}
# {'genres': ['Action', 'Fantasy', 'Sci-Fi'], 'title': 'I, Frankenstein', 'year': 2014}
# {'year': 2010, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Predators'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'The Human Race', 'year': 2013}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'The Wolverine', 'year': 2013}
# {'year': 2012, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Battleship'}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Falling Skies', 'year': '2011è'}
# {'year': 2011, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'I Am Number Four'}
# {'year': 2011, 'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': 'Attack the Block'}
# {'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': 'Redline', 'year': 2009}
# {'year': 2015, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Fantastic Four'}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Gantz', 'year': 2010}
# {'year': 2013, 'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Elysium'}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Ra.One', 'year': 2011}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Chernaya Molniya', 'year': 2009}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Ra.One', 'year': 2011}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'G.I. Joe: Retaliation', 'year': 2013}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Lockout', 'year': 2012}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Jupiter Ascending', 'year': 2015}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Edge of Tomorrow', 'year': 2014}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'In Time', 'year': 2011}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Dead Sea', 'year': 2014}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Pacific Rim', 'year': 2013}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'City Under Siege', 'year': 2010}
# {'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': 'All-Star Superman', 'year': 2011}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Lockout', 'year': 2012}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Battlestar Galactica: Blood & Chrome', 'year': 2012}
# {'year': 2013, 'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Snowpiercer'}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': '7 Aum Arivu', 'year': 2011}
# {'year': 2013, 'genres': ['Action', 'Sci-Fi'], 'title': "Ender's Game"}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Red Eagle', 'year': 2010}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Agency of Vengeance: Dark Rising', 'year': 2011}
# {'genres': ['Action', 'Mystery', 'Sci-Fi'], 'title': 'The Maze Runner', 'year': 2014}
# {'year': 2014, 'genres': ['Action', 'Mystery', 'Sci-Fi'], 'title': 'The Maze Runner'}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'After Earth', 'year': 2013}
# {'year': 2013, 'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': 'Big Ass Spider!'}
# {'year': 2014, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Captain America: The Winter Soldier'}
# {'year': 2012, 'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Resident Evil: Retribution'}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'X-Men: Days of Future Past', 'year': 2014}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Haunters', 'year': 2010}
# {'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'Another World', 'year': 2015}
# {'year': 2013, 'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': "Frankenstein's Army"}
# {'year': 2014, 'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Automata'}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Guardians of the Galaxy', 'year': 2014}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Real Playing Game', 'year': 2013}
# {'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': '009 Re: Cyborg', 'year': 2012}
# {'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': 'Starship Troopers: Invasion', 'year': 2012}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Jupiter Ascending', 'year': 2015}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Dawn of the Planet of the Apes', 'year': 2014}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Transformers: Age of Extinction', 'year': 2014}
# {'year': 2015, 'genres': ['Action', 'Comedy', 'Sci-Fi'], 'title': 'Pixels'}
# {'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': 'Mass Effect: Paragon Lost', 'year': 2012}
# {'year': 2014, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Guardians of the Galaxy'}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Maattrraan', 'year': 2012}
# {'genres': ['Short', 'Action', 'Sci-Fi'], 'title': 'Marvel One-Shot: Item 47', 'year': 2012}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Halo 4: Forward Unto Dawn', 'year': 2012}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Avengers: Age of Ultron', 'year': 2015}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Left Behind', 'year': 2014}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Starship: Rising', 'year': 2014}
# {'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': 'Ghost in the Shell Arise: Border 1 - Ghost Pain', 'year': 2013}
# {'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': 'Iron Man: Rise of Technovore', 'year': 2013}
# {'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Young Ones', 'year': 2014}
# {'genres': ['Action', 'Fantasy', 'Sci-Fi'], 'title': 'P-51 Dragon Fighter', 'year': 2014}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'The Hybrid', 'year': 2014}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'Lucy', 'year': 2014}
# {'genres': ['Action', 'Sci-Fi', 'Thriller'], 'title': 'The Anomaly', 'year': 2014}
# {'year': 2014, 'genres': ['Action', 'Horror', 'Sci-Fi'], 'title': 'The Purge: Anarchy'}
# {'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': 'JLA Adventures: Trapped in Time', 'year': 2014}
# {'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': 'Avengers Confidential: Black Widow & Punisher', 'year': 2014}
# {'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': 'Appleseed Alpha', 'year': 2014}
# {'genres': ['Action', 'Sci-Fi'], 'title': 'Turbo Kid', 'year': 2015}
# {'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Halo: Nightfall', 'year': '2014è'}
# {'genres': ['Animation', 'Action', 'Sci-Fi'], 'title': 'Iron Man and Captain America: Heroes United', 'year': 2014}

# %% [markdown]
# **5. 정렬하기(sort), 앞쪽 일부 건너뛰기(skip), 갯수 제한하기(limit):**
# - find() 에 붙여서, 별도 메서드로 사용

# %%
list(movies.find().sort("imdb.rating", -1).skip(3).limit(3) )
# db.movies.find().sort( { "imdb.rating": -1 } ).skip(3).limit(3)
# Out:
# [{'_id': ObjectId('573a13d3f29313caabd9473c'),
#   'plot': 'As profiled in the film "Aging Out", Risa Bejarano was a foster care success story. Recently graduated, she set out for college with multiple scholarships and a sense of excitement about ...',
#   'genres': ['Documentary'],
#   'title': 'No Tomorrow',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjI2OTgxODExOF5BMl5BanBnXkFtZTgwMzQ3NTA2MDE@._V1_SY1000_SX677_AL_.jpg',
#   'countries': ['USA'],
#   'fullplot': 'As profiled in the film "Aging Out", Risa Bejarano was a foster care success story. Recently graduated, she set out for college with multiple scholarships and a sense of excitement about her future. Then, she was brutally murdered. Soon, "Aging Out" became the centerpiece of Risa\'s murder trial, as prosecutors used the film to heighten sympathy for the victim and hatred for the defendant. Troubled that their documentary was being used to advance the prosecutor\'s argument for the death penalty, filmmakers Vanessa Roth (Academy Aware winner, Freeheld) and Roger Weisberg (Academy Award nominee, Sound and Fury, Why Can\'t We Be A Family Again?) made a new film, "No Tomorrow", which focuses on the trial and the unexpected use of "Aging Out" as evidence. In "No Tomorrow", similarities emerge between Risa and her killer, and viewers are forced to question not just whether the accused deserves to die, but whether the state deserves to kill. Through extensive interviews with those involved in the trial and tense courtroom footage, "No Tomorrow" poses a difficult question: What role did the filmmakers\' previous documentary play in this chilling death penalty trial?',
#   'languages': ['English'],
#   'directors': ['Vanessa Roth'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2014-10-05 00:35:42.680000000',
#   'year': 2010,
#   'imdb': {'rating': '', 'votes': '', 'id': 1877727},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 7, 'meter': 50},
#    'lastUpdated': datetime.datetime(2015, 3, 2, 18, 18, 27)}},
#  {'_id': ObjectId('573a13cff29313caabd88f5b'),
#   'plot': 'Three scouts, on the eve of their last camp-out, discover the true meaning of friendship when they attempt to save their town from a zombie outbreak.',
#   'genres': ['Comedy', 'Horror'],
#   'runtime': 93,
#   'rated': 'R',
#   'cast': ['Halston Sage',
#    'Tye Sheridan',
#    'Patrick Schwarzenegger',
#    'Cloris Leachman'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTY4NjczNjE4OV5BMl5BanBnXkFtZTgwODk0MjQ5NjE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Scouts Guide to the Zombie Apocalypse',
#   'fullplot': 'Three scouts, on the eve of their last camp-out, discover the true meaning of friendship when they attempt to save their town from a zombie outbreak.',
#   'languages': ['English'],
#   'released': datetime.datetime(2015, 10, 30, 0, 0),
#   'directors': ['Christopher Landon'],
#   'writers': ['Emi Mochizuki (screenplay)',
#    'Carrie Lee Wilson (screenplay)',
#    'Christopher Landon (screenplay)',
#    'Lona Williams (screenplay)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-08-27 00:00:19.697000000',
#   'year': 2015,
#   'imdb': {'rating': '', 'votes': '', 'id': 1727776},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 2.8, 'numReviews': 91},
#    'website': 'http://www.scoutsandzombiesmovie.com/',
#    'production': 'Paramount Pictures',
#    'lastUpdated': datetime.datetime(2015, 8, 30, 20, 13, 8)}},
#  {'_id': ObjectId('573a13b8f29313caabd4d540'),
#   'plot': "The remarkable love story inspired by the lives of artists Lili Elbe and Gerda Wegener. Lili and Gerda's marriage and work evolve as they navigate Lili's groundbreaking journey as a transgender pioneer.",
#   'genres': ['Biography', 'Drama'],
#   'runtime': 120,
#   'cast': ['Alicia Vikander',
#    'Eddie Redmayne',
#    'Amber Heard',
#    'Matthias Schoenaerts'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjA0NjA4NjE2Nl5BMl5BanBnXkFtZTgwNzIxNTY2NjE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Danish Girl',
#   'fullplot': "Copenhagen, early 1920s. Danish artist, Gerda Wegener, painted her own husband, Einar Wegener (Eddie Redmayne), as a lady in her painting. When the painting gained popularity, Einar started to change his appearance into a female appearance and named himself Lili Elbe. With his feminism passion and Gerda's support, Einar - or Elbe attempted first-ever male to female sex reassignment surgery, a decision that turned into a massive change for their marriage, that Gerda realized her own husband is no longer a man or the person she married before. A childhood friend of Einar, art-dealer Hans Axgil (Matthias Schoenaerts), shows up and forms a complex love triangle with the couple.",
#   'languages': ['English'],
#   'released': datetime.datetime(2015, 11, 27, 0, 0),
#   'directors': ['Tom Hooper'],
#   'writers': ['David Ebershoff (novel)', 'Lucinda Coxon (screenplay)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-09-01 01:17:41.067000000',
#   'year': 2015,
#   'imdb': {'rating': '', 'votes': '', 'id': 810819},
#   'countries': ['USA', 'UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 300},
#    'lastUpdated': datetime.datetime(2015, 9, 10, 17, 15, 10)}}]

# %%
for movie in movies.find().sort("imdb.rating", -1).skip(3).limit(3):  # -1은 내림차순을 의미합니다.
    print(movie)
# Out:
# {'_id': ObjectId('573a13d3f29313caabd9473c'), 'plot': 'As profiled in the film "Aging Out", Risa Bejarano was a foster care success story. Recently graduated, she set out for college with multiple scholarships and a sense of excitement about ...', 'genres': ['Documentary'], 'title': 'No Tomorrow', 'poster': 'https://m.media-amazon.com/images/M/MV5BMjI2OTgxODExOF5BMl5BanBnXkFtZTgwMzQ3NTA2MDE@._V1_SY1000_SX677_AL_.jpg', 'countries': ['USA'], 'fullplot': 'As profiled in the film "Aging Out", Risa Bejarano was a foster care success story. Recently graduated, she set out for college with multiple scholarships and a sense of excitement about her future. Then, she was brutally murdered. Soon, "Aging Out" became the centerpiece of Risa\'s murder trial, as prosecutors used the film to heighten sympathy for the victim and hatred for the defendant. Troubled that their documentary was being used to advance the prosecutor\'s argument for the death penalty, filmmakers Vanessa Roth (Academy Aware winner, Freeheld) and Roger Weisberg (Academy Award nominee, Sound and Fury, Why Can\'t We Be A Family Again?) made a new film, "No Tomorrow", which focuses on the trial and the unexpected use of "Aging Out" as evidence. In "No Tomorrow", similarities emerge between Risa and her killer, and viewers are forced to question not just whether the accused deserves to die, but whether the state deserves to kill. Through extensive interviews with those involved in the trial and tense courtroom footage, "No Tomorrow" poses a difficult question: What role did the filmmakers\' previous documentary play in this chilling death penalty trial?', 'languages': ['English'], 'directors': ['Vanessa Roth'], 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2014-10-05 00:35:42.680000000', 'year': 2010, 'imdb': {'rating': '', 'votes': '', 'id': 1877727}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 7, 'meter': 50}, 'lastUpdated': datetime.datetime(2015, 3, 2, 18, 18, 27)}}
# {'_id': ObjectId('573a13cff29313caabd88f5b'), 'plot': 'Three scouts, on the eve of their last camp-out, discover the true meaning of friendship when they attempt to save their town from a zombie outbreak.', 'genres': ['Comedy', 'Horror'], 'runtime': 93, 'rated': 'R', 'cast': ['Halston Sage', 'Tye Sheridan', 'Patrick Schwarzenegger', 'Cloris Leachman'], 'num_mflix_comments': 1, 'poster': 'https://m.media-amazon.com/images/M/MV5BMTY4NjczNjE4OV5BMl5BanBnXkFtZTgwODk0MjQ5NjE@._V1_SY1000_SX677_AL_.jpg', 'title': 'Scouts Guide to the Zombie Apocalypse', 'fullplot': 'Three scouts, on the eve of their last camp-out, discover the true meaning of friendship when they attempt to save their town from a zombie outbreak.', 'languages': ['English'], 'released': datetime.datetime(2015, 10, 30, 0, 0), 'directors': ['Christopher Landon'], 'writers': ['Emi Mochizuki (screenplay)', 'Carrie Lee Wilson (screenplay)', 'Christopher Landon (screenplay)', 'Lona Williams (screenplay)'], 'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}, 'lastupdated': '2015-08-27 00:00:19.697000000', 'year': 2015, 'imdb': {'rating': '', 'votes': '', 'id': 1727776}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 2.8, 'numReviews': 91}, 'website': 'http://www.scoutsandzombiesmovie.com/', 'production': 'Paramount Pictures', 'lastUpdated': datetime.datetime(2015, 8, 30, 20, 13, 8)}}
# {'_id': ObjectId('573a13b8f29313caabd4d540'), 'plot': "The remarkable love story inspired by the lives of artists Lili Elbe and Gerda Wegener. Lili and Gerda's marriage and work evolve as they navigate Lili's groundbreaking journey as a transgender pioneer.", 'genres': ['Biography', 'Drama'], 'runtime': 120, 'cast': ['Alicia Vikander', 'Eddie Redmayne', 'Amber Heard', 'Matthias Schoenaerts'], 'num_mflix_comments': 1, 'poster': 'https://m.media-amazon.com/images/M/MV5BMjA0NjA4NjE2Nl5BMl5BanBnXkFtZTgwNzIxNTY2NjE@._V1_SY1000_SX677_AL_.jpg', 'title': 'The Danish Girl', 'fullplot': "Copenhagen, early 1920s. Danish artist, Gerda Wegener, painted her own husband, Einar Wegener (Eddie Redmayne), as a lady in her painting. When the painting gained popularity, Einar started to change his appearance into a female appearance and named himself Lili Elbe. With his feminism passion and Gerda's support, Einar - or Elbe attempted first-ever male to female sex reassignment surgery, a decision that turned into a massive change for their marriage, that Gerda realized her own husband is no longer a man or the person she married before. A childhood friend of Einar, art-dealer Hans Axgil (Matthias Schoenaerts), shows up and forms a complex love triangle with the couple.", 'languages': ['English'], 'released': datetime.datetime(2015, 11, 27, 0, 0), 'directors': ['Tom Hooper'], 'writers': ['David Ebershoff (novel)', 'Lucinda Coxon (screenplay)'], 'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}, 'lastupdated': '2015-09-01 01:17:41.067000000', 'year': 2015, 'imdb': {'rating': '', 'votes': '', 'id': 810819}, 'countries': ['USA', 'UK'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 300}, 'lastUpdated': datetime.datetime(2015, 9, 10, 17, 15, 10)}}

# %% [markdown]
# **6. 정규표현식과 pymongo**
#
# -  파이썬의 정규표현식 라이브러리인 `re` 모듈의 `compile` 함수를 사용하여 정규 표현식 객체를 생성하고,
# - 이를 pymongo 에 적용할 수 있습니다.
#
# - 예: re.I (IGNORECASE): 이 옵션은 대소문자를 구분하지 않는다는 것을 나타냅니다. 따라서 'Star', 'STAR', 'star', 'sTaR' 등을 모두 찾을 수 있습니다.

# %%
import re
regex = re.compile('Star', re.I)  # 'Star'를 대소문자를 구분하지 않고 검색합니다.

for movie in movies.find({"title": regex}).limit(1): # title에 'Star'가 포함된 영화 찾기
    print(movie)
# Out:
# {'_id': ObjectId('573a1392f29313caabcdb497'), 'plot': 'A young woman comes to Hollywood with dreams of stardom, but achieves them only with the help of an alcoholic leading man whose best days are behind him.', 'genres': ['Drama'], 'runtime': 111, 'rated': 'NOT RATED', 'cast': ['Janet Gaynor', 'Fredric March', 'Adolphe Menjou', 'May Robson'], 'poster': 'https://m.media-amazon.com/images/M/MV5BMmE5ODI0NzMtYjc5Yy00MzMzLTk5OTQtN2Q3MzgwOTllMTY3XkEyXkFqcGdeQXVyNjc0MzMzNjA@._V1_SY1000_SX677_AL_.jpg', 'title': 'A Star Is Born', 'fullplot': 'Esther Blodgett is just another starry-eyed farm kid trying to break into the movies. Waitressing at a Hollywood party, she catches the eye of alcoholic star Norman Maine, is given a test, and is caught up in the Hollywood glamor machine (ruthlessly satirized). She and her idol Norman marry; but his career abruptly dwindles to nothing', 'languages': ['English'], 'released': datetime.datetime(1937, 4, 27, 0, 0), 'directors': ['William A. Wellman', 'Jack Conway'], 'writers': ['Dorothy Parker (screen play)', 'Alan Campbell (screen play)', 'Robert Carson (screen play)', 'William A. Wellman (from a story by)', 'Robert Carson (from a story by)'], 'awards': {'wins': 3, 'nominations': 7, 'text': 'Won 1 Oscar. Another 2 wins & 7 nominations.'}, 'lastupdated': '2015-09-01 00:55:54.333000000', 'year': 1937, 'imdb': {'rating': 7.7, 'votes': 5005, 'id': 29606}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'website': 'http://www.vcientertainment.com/Film-Categories?product_id=73', 'viewer': {'rating': 3.6, 'numReviews': 2526, 'meter': 79}, 'dvd': datetime.datetime(2004, 11, 16, 0, 0), 'critic': {'rating': 7.4, 'numReviews': 11, 'meter': 100}, 'lastUpdated': datetime.datetime(2015, 8, 26, 18, 58, 34), 'rotten': 0, 'production': 'Image Entertainment Inc.', 'fresh': 11}}

# %%
list(movies.find({"title": regex}).limit(1)) # db.movies.find( { title: /Star/i } )
# Out:
# [{'_id': ObjectId('573a1392f29313caabcdb497'),
#   'plot': 'A young woman comes to Hollywood with dreams of stardom, but achieves them only with the help of an alcoholic leading man whose best days are behind him.',
#   'genres': ['Drama'],
#   'runtime': 111,
#   'rated': 'NOT RATED',
#   'cast': ['Janet Gaynor', 'Fredric March', 'Adolphe Menjou', 'May Robson'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMmE5ODI0NzMtYjc5Yy00MzMzLTk5OTQtN2Q3MzgwOTllMTY3XkEyXkFqcGdeQXVyNjc0MzMzNjA@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'A Star Is Born',
#   'fullplot': 'Esther Blodgett is just another starry-eyed farm kid trying to break into the movies. Waitressing at a Hollywood party, she catches the eye of alcoholic star Norman Maine, is given a test, and is caught up in the Hollywood glamor machine (ruthlessly satirized). She and her idol Norman marry; but his career abruptly dwindles to nothing',
#   'languages': ['English'],
#   'released': datetime.datetime(1937, 4, 27, 0, 0),
#   'directors': ['William A. Wellman', 'Jack Conway'],
#   'writers': ['Dorothy Parker (screen play)',
#    'Alan Campbell (screen play)',
#    'Robert Carson (screen play)',
#    'William A. Wellman (from a story by)',
#    'Robert Carson (from a story by)'],
#   'awards': {'wins': 3,
#    'nominations': 7,
#    'text': 'Won 1 Oscar. Another 2 wins & 7 nominations.'},
#   'lastupdated': '2015-09-01 00:55:54.333000000',
#   'year': 1937,
#   'imdb': {'rating': 7.7, 'votes': 5005, 'id': 29606},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.vcientertainment.com/Film-Categories?product_id=73',
#    'viewer': {'rating': 3.6, 'numReviews': 2526, 'meter': 79},
#    'dvd': datetime.datetime(2004, 11, 16, 0, 0),
#    'critic': {'rating': 7.4, 'numReviews': 11, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 58, 34),
#    'rotten': 0,
#    'production': 'Image Entertainment Inc.',
#    'fresh': 11}}]

# %% [markdown]
# - re 모듈 없이, 직접 정규표현식을 pymongo 에 사용할 수도 있음
# - `$options`
#    - `i`: 대소문자를 구분하지 않습니다. (re 라이브러리에서는 re.I)

# %%
# title에 'Star'가 포함된 영화 찾기
list(movies.find({"title": regex}).limit(1)) # db.movies.find( { title: /Star/i } )
# Out:
# [{'_id': ObjectId('573a1392f29313caabcdb497'),
#   'plot': 'A young woman comes to Hollywood with dreams of stardom, but achieves them only with the help of an alcoholic leading man whose best days are behind him.',
#   'genres': ['Drama'],
#   'runtime': 111,
#   'rated': 'NOT RATED',
#   'cast': ['Janet Gaynor', 'Fredric March', 'Adolphe Menjou', 'May Robson'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMmE5ODI0NzMtYjc5Yy00MzMzLTk5OTQtN2Q3MzgwOTllMTY3XkEyXkFqcGdeQXVyNjc0MzMzNjA@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'A Star Is Born',
#   'fullplot': 'Esther Blodgett is just another starry-eyed farm kid trying to break into the movies. Waitressing at a Hollywood party, she catches the eye of alcoholic star Norman Maine, is given a test, and is caught up in the Hollywood glamor machine (ruthlessly satirized). She and her idol Norman marry; but his career abruptly dwindles to nothing',
#   'languages': ['English'],
#   'released': datetime.datetime(1937, 4, 27, 0, 0),
#   'directors': ['William A. Wellman', 'Jack Conway'],
#   'writers': ['Dorothy Parker (screen play)',
#    'Alan Campbell (screen play)',
#    'Robert Carson (screen play)',
#    'William A. Wellman (from a story by)',
#    'Robert Carson (from a story by)'],
#   'awards': {'wins': 3,
#    'nominations': 7,
#    'text': 'Won 1 Oscar. Another 2 wins & 7 nominations.'},
#   'lastupdated': '2015-09-01 00:55:54.333000000',
#   'year': 1937,
#   'imdb': {'rating': 7.7, 'votes': 5005, 'id': 29606},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.vcientertainment.com/Film-Categories?product_id=73',
#    'viewer': {'rating': 3.6, 'numReviews': 2526, 'meter': 79},
#    'dvd': datetime.datetime(2004, 11, 16, 0, 0),
#    'critic': {'rating': 7.4, 'numReviews': 11, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 58, 34),
#    'rotten': 0,
#    'production': 'Image Entertainment Inc.',
#    'fresh': 11}}]

# %%
for movie in movies.find({"title": {"$regex": "star", "$options": 'i'}}).limit(1): 
    print(movie)
# Out:
# {'_id': ObjectId('573a1392f29313caabcdb497'), 'plot': 'A young woman comes to Hollywood with dreams of stardom, but achieves them only with the help of an alcoholic leading man whose best days are behind him.', 'genres': ['Drama'], 'runtime': 111, 'rated': 'NOT RATED', 'cast': ['Janet Gaynor', 'Fredric March', 'Adolphe Menjou', 'May Robson'], 'poster': 'https://m.media-amazon.com/images/M/MV5BMmE5ODI0NzMtYjc5Yy00MzMzLTk5OTQtN2Q3MzgwOTllMTY3XkEyXkFqcGdeQXVyNjc0MzMzNjA@._V1_SY1000_SX677_AL_.jpg', 'title': 'A Star Is Born', 'fullplot': 'Esther Blodgett is just another starry-eyed farm kid trying to break into the movies. Waitressing at a Hollywood party, she catches the eye of alcoholic star Norman Maine, is given a test, and is caught up in the Hollywood glamor machine (ruthlessly satirized). She and her idol Norman marry; but his career abruptly dwindles to nothing', 'languages': ['English'], 'released': datetime.datetime(1937, 4, 27, 0, 0), 'directors': ['William A. Wellman', 'Jack Conway'], 'writers': ['Dorothy Parker (screen play)', 'Alan Campbell (screen play)', 'Robert Carson (screen play)', 'William A. Wellman (from a story by)', 'Robert Carson (from a story by)'], 'awards': {'wins': 3, 'nominations': 7, 'text': 'Won 1 Oscar. Another 2 wins & 7 nominations.'}, 'lastupdated': '2015-09-01 00:55:54.333000000', 'year': 1937, 'imdb': {'rating': 7.7, 'votes': 5005, 'id': 29606}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'website': 'http://www.vcientertainment.com/Film-Categories?product_id=73', 'viewer': {'rating': 3.6, 'numReviews': 2526, 'meter': 79}, 'dvd': datetime.datetime(2004, 11, 16, 0, 0), 'critic': {'rating': 7.4, 'numReviews': 11, 'meter': 100}, 'lastUpdated': datetime.datetime(2015, 8, 26, 18, 58, 34), 'rotten': 0, 'production': 'Image Entertainment Inc.', 'fresh': 11}}

# %% [markdown]
# **7. distinct: 이 메소드는 특정 필드의 모든 고유한 값을 반환합니다.**

# %%
distinct_genres = movies.distinct('genres') # db.movies.distinct("genres")
print(distinct_genres)
# Out:
# ['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'Film-Noir', 'History', 'Horror', 'Music', 'Musical', 'Mystery', 'News', 'Romance', 'Sci-Fi', 'Short', 'Sport', 'Talk-Show', 'Thriller', 'War', 'Western']

# %% [markdown]
# **8. $in: 이 연산자는 필드 값이 특정 배열 내의 값 중 하나와 일치하는 문서를 선택합니다.**

# %%
movies.find({'genres': {'$in': ['Action', 'Adventure']}}).limit(3) 
# db.movies.find( { genres: { $in: [ "Action", "Adventure" ] } } ).limit(3)
# 'Action' 또는 'Adventure' 장르의 영화 찾기

# %%
for movie in movies.find({'genres': {'$in': ['Action', 'Adventure']}}).limit(3):
    print(movie['genres'])
# Out:
# ['Action']
# ['Action', 'Adventure', 'Crime']
# ['Comedy', 'Short', 'Action']

# %% [markdown]
# **9. $exists: 이 연산자는 특정 필드가 문서에 존재하는지 여부에 따라 문서를 선택합니다.**

# %%
movies.find({'writers': {'$exists': False}}).limit(3) 
# db.movies.find( { writers: { $exists: false } } ).limit(3)
# 'writers' 필드가 존재하지 않는 영화 찾기

# %%
for movie in movies.find({'writers': {'$exists': False}}).limit(3):
    print(movie)
# Out:
# {'_id': ObjectId('573a1390f29313caabcd4135'), 'plot': 'Three men hammer on an anvil and pass a bottle of beer around.', 'genres': ['Short'], 'runtime': 1, 'cast': ['Charles Kayser', 'John Ott'], 'num_mflix_comments': 1, 'title': 'Blacksmith Scene', 'fullplot': 'A stationary camera looks at a large anvil with a blacksmith behind it and one on either side. The smith in the middle draws a heated metal rod from the fire, places it on the anvil, and all three begin a rhythmic hammering. After several blows, the metal goes back in the fire. One smith pulls out a bottle of beer, and they each take a swig. Then, out comes the glowing metal and the hammering resumes.', 'countries': ['USA'], 'released': datetime.datetime(1893, 5, 9, 0, 0), 'directors': ['William K.L. Dickson'], 'rated': 'UNRATED', 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-08-26 00:03:50.133000000', 'year': 1893, 'imdb': {'rating': 6.2, 'votes': 1189, 'id': 5}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.0, 'numReviews': 184, 'meter': 32}, 'lastUpdated': datetime.datetime(2015, 6, 28, 18, 34, 9)}}
# {'_id': ObjectId('573a1390f29313caabcd42e8'), 'plot': 'A group of bandits stage a brazen train hold-up, only to find a determined posse hot on their heels.', 'genres': ['Short', 'Western'], 'runtime': 11, 'cast': ['A.C. Abadie', "Gilbert M. 'Broncho Billy' Anderson", 'George Barnes', 'Justus D. Barnes'], 'poster': 'https://m.media-amazon.com/images/M/MV5BMTU3NjE5NzYtYTYyNS00MDVmLWIwYjgtMmYwYWIxZDYyNzU2XkEyXkFqcGdeQXVyNzQzNzQxNzI@._V1_SY1000_SX677_AL_.jpg', 'title': 'The Great Train Robbery', 'fullplot': "Among the earliest existing films in American cinema - notable as the first film that presented a narrative story to tell - it depicts a group of cowboy outlaws who hold up a train and rob the passengers. They are then pursued by a Sheriff's posse. Several scenes have color included - all hand tinted.", 'languages': ['English'], 'released': datetime.datetime(1903, 12, 1, 0, 0), 'directors': ['Edwin S. Porter'], 'rated': 'TV-G', 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-08-13 00:27:59.177000000', 'year': 1903, 'imdb': {'rating': 7.4, 'votes': 9847, 'id': 439}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 2559, 'meter': 75}, 'fresh': 6, 'critic': {'rating': 7.6, 'numReviews': 6, 'meter': 100}, 'rotten': 0, 'lastUpdated': datetime.datetime(2015, 8, 8, 19, 16, 10)}}
# {'_id': ObjectId('573a1390f29313caabcd446f'), 'plot': "A greedy tycoon decides, on a whim, to corner the world market in wheat. This doubles the price of bread, forcing the grain's producers into charity lines and further into poverty. The film...", 'genres': ['Short', 'Drama'], 'runtime': 14, 'cast': ['Frank Powell', 'Grace Henderson', 'James Kirkwood', 'Linda Arvidson'], 'num_mflix_comments': 1, 'title': 'A Corner in Wheat', 'fullplot': "A greedy tycoon decides, on a whim, to corner the world market in wheat. This doubles the price of bread, forcing the grain's producers into charity lines and further into poverty. The film continues to contrast the ironic differences between the lives of those who work to grow the wheat and the life of the man who dabbles in its sale for profit.", 'languages': ['English'], 'released': datetime.datetime(1909, 12, 13, 0, 0), 'directors': ['D.W. Griffith'], 'rated': 'G', 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-08-13 00:46:30.660000000', 'year': 1909, 'imdb': {'rating': 6.6, 'votes': 1375, 'id': 832}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 109, 'meter': 73}, 'lastUpdated': datetime.datetime(2015, 5, 11, 18, 36, 53)}}

# %% [markdown]
# **10. count_documents: 이 메소드는 쿼리에 일치하는 문서의 수를 반환합니다.**
# - find() 대신에 count_documents() 메서드로 count 값을 얻을 수 있음
#
# > find().count() 방식도 문서의 수를 세는 방법으로 사용할 수 있지만, 이 방식은 MongoDB 4.0 이후로 공식적으로 deprecated (사용이 권장되지 않는) 되었습니다.

# %%
# 'Action' 또는 'Adventure' 장르의 영화 개수 세기
count = movies.count_documents({'genres': {'$in': ['Action', 'Adventure']}}) 
# db.movies.countDocuments( { genres: { $in: [ "Action", "Adventure" ] } } )
print(count)
# Out:
# 3805
